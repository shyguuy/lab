# %% [markdown]
# <a href="https://colab.research.google.com/github/shyguuy/lab/blob/main/lab1/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("cwurData.csv")
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
df.iloc[0:5,0]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: world_rank, dtype: int64

# %%
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df.tail()
# Out:
#       world_rank                      institution   country  national_rank  \
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 2195                   367                567                 218
# 2196                   236                566                 218
# 2197                   367                549                 218
# 2198                   367                567                 218
# 2199                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year
# ...

# %%
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.**
# 2.   **Ответ 2.**

# %%
df.mean(numeric_only=True)
# Out:
# world_rank               459.590909
# national_rank             40.278182
# quality_of_education     275.100455
# alumni_employment        357.116818
# quality_of_faculty       178.888182
# publications             459.908636
# influence                459.797727
# citations                413.417273
# broad_impact             496.699500
# patents                  433.346364
# score                     47.798395
# year                    2014.318182
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# world_rank                 1.00
# national_rank              1.00
# quality_of_education       1.00
# alumni_employment          1.00
# quality_of_faculty         1.00
# publications               1.00
# influence                  1.00
# citations                  1.00
# broad_impact               1.00
# patents                    1.00
# score                     43.36
# year                    2012.00
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# world_rank              1000.0
# national_rank            229.0
# quality_of_education     367.0
# alumni_employment        567.0
# quality_of_faculty       218.0
# publications            1000.0
# influence                991.0
# citations                812.0
# broad_impact            1000.0
# patents                  871.0
# score                    100.0
# year                    2015.0
# dtype: float64

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df.dropna()
df[' institution'] = df[' institution'].astype('category')
df[' year'] = df[' year'].astype('category')
df[' country'] = df[' country'].astype('category')
df.info()

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# Категориальные, количественные, порядковые

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
df[df['year'] == 2013]
# Out:
#      world_rank                            institution         country  \
# 100           1                     Harvard University             USA
# 101           2                    Stanford University             USA
# 102           3                   University of Oxford  United Kingdom
# 103           4  Massachusetts Institute of Technology             USA
# 104           5                University of Cambridge  United Kingdom
# ..          ...                                    ...             ...
# 195          96         Australian National University       Australia
# 196          97                  University of Alberta          Canada
# 197          98                 University of Helsinki         Finland
# 198          99     Paris Diderot University - Paris 7          France
# 199         100        Georgia Institute of Technology             USA
#
#      national_rank  quality_of_education  alumni_employment  \
# ...

# %%
df[(df['national_rank'] < 20) & ((df['quality_of_education'] > 100)&(df['quality_of_education'] < 200))]
# Out:
#       world_rank                                        institution  \
# 23            24            University of California, San Francisco
# 34            35                              University of Toronto
# 66            67                     University of British Columbia
# 68            69  Swiss Federal Institute of Technology in Lausanne
# 74            75                          Seoul National University
# ...          ...                                                ...
# 1929         730                                Université de Namur
# 1967         768                               University of Tehran
# 2089         890               Adam Mickiewicz University in Poznań
# 2090         891                             University of Calcutta
# 2184         985                       Novosibirsk State University
#
#           country  national_rank  quality_of_education  alumni_employment  \
# 23            USA             17                   101                101
# ...

# %%
df[df['score'] >= 70]
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 1211          12     California Institute of Technology             USA
# 1212          13                    University of Tokyo           Japan
# 1213          14             University of Pennsylvania             USA
# 1214          15  University of California, Los Angeles             USA
# 1215          16               Johns Hopkins University             USA
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df.groupby('country').mean()
# Out:
# <ipython-input-20-d1697acfd951>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('country').mean()
#                       world_rank  national_rank  quality_of_education  \
# country
# Argentina             719.714286       2.285714            302.428571
# Australia             497.310345      13.137931            287.120690
# Austria               551.625000       6.500000            331.458333
# Belgium               362.300000       5.500000            247.700000
# Brazil                748.361111       9.500000            348.250000
# Bulgaria              835.500000       1.000000            244.000000
# Canada                400.236111      15.347222            287.041667
# Chile                 654.375000       2.500000            323.875000
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
